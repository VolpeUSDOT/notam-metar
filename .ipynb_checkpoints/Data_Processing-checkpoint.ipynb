# %% [markdown]
# # NOTAM + METAR Data Processing
#
# Goals:
# - Summarize available NOTAM data from prepared notam_extract file.
# - Select example set of facilities (airports) and obtain METARs for the corresponding facilities and date ranges.
#     + Obtain METARs by accessing API
#     + Focus on ceiling and runway visual range. Will require some regular expression processing to extract cloud ceiling altitutde. Take the minimum value of each at each facility and time point.
# - Integrate the two. Will require decisions on temporal resolution.
# - Prepare data for visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from os import path
import seaborn as sns
pd.options.display.max_rows = 100

# %%
# Read NOTAM extract. Obtain data file from shared Box.com site and place in ~/Documents/Notam_local
data_dir = r'~\Documents\Notam_Local' 

notam = pd.read_excel(path.join(data_dir, 'notam_extract.xlsx'), sheet_name = "data", header = 0)

# %%
notam.head()
# Out:
#   notam_location             start_time               end_time keyword  \
# 0           KSZY  2019-04-02 01:44:00.0  2019-04-17 00:44:00.0    OBST
# 1           KCXW  2019-04-02 01:46:00.0  2019-04-17 00:46:00.0    OBST
# 2           KUOS  2019-04-02 01:49:00.0  2019-04-17 00:49:00.0    OBST
# 3            M95  2019-04-02 01:50:00.0  2019-04-17 00:50:00.0    OBST
# 4            2A8  2019-04-02 01:54:00.0  2019-04-17 00:54:00.0    OBST
#
#                                                 text
# 0  OBST TOWER LGT (ASR 1269190) 352126.80N0882231...
# 1  OBST TOWER LGT (ASR 1212822) 345040.40N0923322...
# 2  OBST TOWER LGT (ASR 1052889) 351222.50N0854828...
# 3  OBST TOWER LGT (ASR 1248915) 334516.20N0875825...
# 4  OBST TOWER LGT (ASR 1280021) 340633.40N0870610...

# %%
# Choose locations with more than 100 NOTAMs
selection = notam.groupby('notam_location').agg({'start_time': 'min', 'end_time': 'max', 'keyword': 'count'})
filtered_selection = selection[(selection.keyword > 100)]
filtered_selection
# Out:
#                            start_time               end_time  keyword
# notam_location
# KDVL            2019-01-10 01:00:00.0  2019-05-31 06:00:00.0      142
# KDVT            2018-10-06 09:27:00.0  2019-06-28 22:44:00.0      270
# KFMY            2018-09-19 13:31:00.0  2019-05-31 18:00:00.0      256
# KHUA            2019-03-15 13:00:00.0  2019-06-07 17:00:00.0      146
# KLAX            2019-02-27 17:20:00.0  2019-06-14 19:30:00.0      108
# KLCQ            2019-01-02 19:45:00.0  2019-06-03 06:29:00.0      152
# KMCO            2018-12-28 10:20:00.0  2019-06-30 18:00:00.0      337
# KMOB            2019-03-26 11:20:00.0  2019-06-30 19:00:00.0      128
# KMSY            2017-04-26 11:40:00.0  2019-06-30 18:00:00.0      207
# KPHL            2018-12-14 05:00:00.0  2019-06-30 06:00:00.0      202
# KTUS            2018-11-19 10:00:00.0  2019-05-30 20:30:00.0      194
# TJSJ            2018-12-28 10:32:00.0  2019-06-30 17:00:00.0      341

# %%
# Extract these locations for use in METAR downloading
focal_loc = filtered_selection.index.values
focal_loc[0] # Showing this is now a list
# Out:
# 'KDVL'

# %% [markdown]
# ## Get METARs for these locations and times
#
# - https://mesonet.agron.iastate.edu/request/download.phtml
# - https://github.com/akrherz/iem/blob/master/scripts/asos/iem_scraper_example.py
#
# To do:
# - adapt functions from `iem_scraper_example.py`, currently in `metar_scraper.py`
# - Change main to use the specific start_time and end_time from filtered_selection data frame
# - Consider compiling in one file rather than downloading separately by station
# - Work on integrating METAR and NOTAM data and visualizing.

# %%
# Edit in metar_scraper.py, and uncomment next line to reload -- or consider using "import metar_scraper", but didn't work for me
# %load metar_scraper
"""
Adapted from https://github.com/akrherz/iem/edit/master/scripts/asos/iem_scraper_example.py
Example script that scrapes data from the IEM ASOS download service
"""
from __future__ import print_function
import json
import time
import datetime
# Python 2 and 3: alternative 4
try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen

# Number of attempts to download data
MAX_ATTEMPTS = 6
# HTTPS here can be problematic for installs that don't have Lets Encrypt CA
SERVICE = "http://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?"

def download_data(uri):
    """Fetch the data from the IEM

    The IEM download service has some protections in place to keep the number
    of inbound requests in check.  This function implements an exponential
    backoff to keep individual downloads from erroring.

    Args:
      uri (string): URL to fetch

    Returns:
      string data
    """
    attempt = 0
    while attempt < MAX_ATTEMPTS:
        try:
            data = urlopen(uri, timeout=300).read().decode('utf-8')
            if data is not None and not data.startswith('ERROR'):
                return data
        except Exception as exp:
            print("download_data(%s) failed with %s" % (uri, exp))
            time.sleep(5)
        attempt += 1

    print("Exhausted attempts to download, returning empty data")
    return ""


def get_stations_from_filelist(filename):
    """Build a listing of stations from a simple file listing the stations.

    The file should simply have one station per line.
    """
    stations = []
    for line in open(filename):
        stations.append(line.strip())
    return stations


def get_stations_from_networks():
    """Build a station list by using a bunch of IEM networks."""
    stations = []
    states = """AK AL AR AZ CA CO CT DE FL GA HI IA ID IL IN KS KY LA MA MD ME
     MI MN MO MS MT NC ND NE NH NJ NM NV NY OH OK OR PA RI SC SD TN TX UT VA VT
     WA WI WV WY"""
    # IEM quirk to have Iowa AWOS sites in its own labeled network
    networks = ['AWOS']
    for state in states.split():
        networks.append("%s_ASOS" % (state,))

    for network in networks:
        # Get metadata
        uri = ("https://mesonet.agron.iastate.edu/"
               "geojson/network/%s.geojson") % (network,)
        data = urlopen(uri)
        jdict = json.load(data)
        for site in jdict['features']:
            stations.append(site['properties']['sid'])
    return stations


def get_metar(stations):
    """
    Our main method
    stations is a list of airports
    """
    # timestamps in UTC to request data for
    startts = datetime.datetime(2012, 8, 1)
    endts = datetime.datetime(2012, 9, 1)

    service = SERVICE + "data=all&tz=Etc/UTC&format=comma&latlon=yes&"

    service += startts.strftime('year1=%Y&month1=%m&day1=%d&')
    service += endts.strftime('year2=%Y&month2=%m&day2=%d&')

    # Two examples of how to specify a list of stations
    # stations = get_stations_from_networks()
    # stations = get_stations_from_filelist("mystations.txt")
    
    for station in stations:
        uri = '%s&station=%s' % (service, station)
        print('Downloading: %s' % (station, ))
        data = download_data(uri)
        outfn = '%s_%s_%s.txt' % (station, startts.strftime("%Y%m%d%H%M"),
                                  endts.strftime("%Y%m%d%H%M"))
        out = open(outfn, 'w')
        out.write(data)
        out.close()


if __name__ == '__main__':
    get_metar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-29eb593950d3> in <module>
#     111
#     112 if __name__ == '__main__':
# --> 113     get_metar()
#
# TypeError: get_metar() missing 1 required positional argument: 'stations'

# %%
get_metar(stations = focal_loc)
# Out:
# Downloading: KDVL
# Downloading: KDVT
# Downloading: KFMY
# Downloading: KHUA
# Downloading: KLAX
# Downloading: KLCQ
# Downloading: KMCO
# Downloading: KMOB
# Downloading: KMSY
# Downloading: KPHL
# Downloading: KTUS
# Downloading: TJSJ

# %%
# View current working directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\Daniel.Flynn\\Documents\\git\\notam-metar'

# %%
notam_now = notam.loc[notam['notam_location'] == 'KDVL']
notam_now
# Out:
#      notam_location             start_time               end_time keyword  \
# 489            KDVL  2019-02-07 01:00:00.0  2019-02-07 05:00:00.0      AD
# 661            KDVL  2019-02-08 01:00:00.0  2019-02-08 05:00:00.0      AD
# 670            KDVL  2019-01-28 01:00:00.0  2019-01-28 05:00:00.0      AD
# 753            KDVL  2019-01-29 01:00:00.0  2019-01-29 05:00:00.0      AD
# 756            KDVL  2019-02-09 01:00:00.0  2019-02-09 05:00:00.0      AD
# 941            KDVL  2019-02-10 01:00:00.0  2019-02-10 05:00:00.0      AD
# 998            KDVL  2019-02-11 01:00:00.0  2019-02-11 05:00:00.0      AD
# 1059           KDVL  2019-02-12 01:00:00.0  2019-02-12 05:00:00.0      AD
# 1109           KDVL  2019-02-13 01:00:00.0  2019-02-13 05:00:00.0      AD
# 1165           KDVL  2019-01-30 01:00:00.0  2019-01-30 05:00:00.0      AD
# 1193           KDVL  2019-01-31 01:00:00.0  2019-01-31 05:00:00.0      AD
# 1232           KDVL  2019-02-14 01:00:00.0  2019-02-14 05:00:00.0      AD
# 1241           KDVL  2019-02-01 01:00:00.0  2019-02-01 05:00:00.0      AD
# 1288           KDVL  2019-02-15 01:00:00.0  2019-02-15 05:00:00.0      AD
# 1301           KDVL  2019-02-02 01:00:00.0  2019-02-02 05:00:00.0      AD
# 1320           KDVL  2019-02-03 01:00:00.0  2019-02-03 05:00:00.0      AD
# 1425           KDVL  2019-02-16 01:00:00.0  2019-02-16 05:00:00.0      AD
# 1428           KDVL  2019-02-04 01:00:00.0  2019-02-04 05:00:00.0      AD
# 1436           KDVL  2019-02-17 01:00:00.0  2019-02-17 05:00:00.0      AD
# 1472           KDVL  2019-02-05 01:00:00.0  2019-02-05 05:00:00.0      AD
# 1483           KDVL  2019-02-06 01:00:00.0  2019-02-06 05:00:00.0      AD
# 1518           KDVL  2019-01-27 01:00:00.0  2019-01-27 05:00:00.0      AD
# 1649           KDVL  2019-01-10 01:00:00.0  2019-01-10 05:00:00.0      AD
# 1650           KDVL  2019-01-11 01:00:00.0  2019-01-11 05:00:00.0      AD
# 1651           KDVL  2019-01-12 01:00:00.0  2019-01-12 05:00:00.0      AD
# 1652           KDVL  2019-01-13 01:00:00.0  2019-01-13 05:00:00.0      AD
# 1653           KDVL  2019-01-14 01:00:00.0  2019-01-14 05:00:00.0      AD
# 1654           KDVL  2019-01-15 01:00:00.0  2019-01-15 05:00:00.0      AD
# 1655           KDVL  2019-01-16 01:00:00.0  2019-01-16 05:00:00.0      AD
# 1656           KDVL  2019-01-17 01:00:00.0  2019-01-17 05:00:00.0      AD
# 1657           KDVL  2019-01-18 01:00:00.0  2019-01-18 05:00:00.0      AD
# 1658           KDVL  2019-01-19 01:00:00.0  2019-01-19 05:00:00.0      AD
# 1059  AD AP SFC COND NOT REP DLY 0600-1000
# 1109  AD AP SFC COND NOT REP DLY 0600-1000
# 1165  AD AP SFC COND NOT REP DLY 0600-1000
# 1193  AD AP SFC COND NOT REP DLY 0600-1000
# 1232  AD AP SFC COND NOT REP DLY 0600-1000
# 1241  AD AP SFC COND NOT REP DLY 0600-1000
# 1288  AD AP SFC COND NOT REP DLY 0600-1000
# 1301  AD AP SFC COND NOT REP DLY 0600-1000
# 1320  AD AP SFC COND NOT REP DLY 0600-1000
# 1425  AD AP SFC COND NOT REP DLY 0600-1000
# 1428  AD AP SFC COND NOT REP DLY 0600-1000
# 1436  AD AP SFC COND NOT REP DLY 0600-1000
# 1472  AD AP SFC COND NOT REP DLY 0600-1000
# 1483  AD AP SFC COND NOT REP DLY 0600-1000
# 1518  AD AP SFC COND NOT REP DLY 0600-1000
# 1649  AD AP SFC COND NOT REP DLY 0600-1000
# 1650  AD AP SFC COND NOT REP DLY 0600-1000
# 1651  AD AP SFC COND NOT REP DLY 0600-1000
# 1652  AD AP SFC COND NOT REP DLY 0600-1000
# 1653  AD AP SFC COND NOT REP DLY 0600-1000
# 1654  AD AP SFC COND NOT REP DLY 0600-1000
# 1655  AD AP SFC COND NOT REP DLY 0600-1000
# 1656  AD AP SFC COND NOT REP DLY 0600-1000
# 1657  AD AP SFC COND NOT REP DLY 0600-1000
# 1658  AD AP SFC COND NOT REP DLY 0600-1000
# 1659  AD AP SFC COND NOT REP DLY 0600-1000
# 1660  AD AP SFC COND NOT REP DLY 0600-1000
# 1661  AD AP SFC COND NOT REP DLY 0600-1000
# 1662  AD AP SFC COND NOT REP DLY 0600-1000
# 1663  AD AP SFC COND NOT REP DLY 0600-1000
# 1664  AD AP SFC COND NOT REP DLY 0600-1000
# 1665  AD AP SFC COND NOT REP DLY 0600-1000
# 1675  AD AP SFC COND NOT REP DLY 0600-1000
# 1676  AD AP SFC COND NOT REP DLY 0600-1000
# 1677  AD AP SFC COND NOT REP DLY 0600-1000
# 1678  AD AP SFC COND NOT REP DLY 0600-1000
# 1679  AD AP SFC COND NOT REP DLY 0600-1000
# 1680  AD AP SFC COND NOT REP DLY 0600-1000
# 1681  AD AP SFC COND NOT REP DLY 0600-1000
# 1682  AD AP SFC COND NOT REP DLY 0600-1000
# 1683  AD AP SFC COND NOT REP DLY 0600-1000
# 1684  AD AP SFC COND NOT REP DLY 0600-1000
# 1685  AD AP SFC COND NOT REP DLY 0600-1000
# ...                                    ...
# 1728  AD AP SFC COND NOT REP DLY 0600-1000
# 1729  AD AP SFC COND NOT REP DLY 0600-1000
# 1730  AD AP SFC COND NOT REP DLY 0600-1000
# 1731  AD AP SFC COND NOT REP DLY 0600-1000
# 1732  AD AP SFC COND NOT REP DLY 0600-1000
# 1733  AD AP SFC COND NOT REP DLY 0600-1000
# 1734  AD AP SFC COND NOT REP DLY 0600-1000
# 1735  AD AP SFC COND NOT REP DLY 0600-1000
# 1736  AD AP SFC COND NOT REP DLY 0600-1000
# 1737  AD AP SFC COND NOT REP DLY 0600-1000
# 1738  AD AP SFC COND NOT REP DLY 0600-1000
# 1739  AD AP SFC COND NOT REP DLY 0600-1000
# 1740  AD AP SFC COND NOT REP DLY 0600-1000
# 1741  AD AP SFC COND NOT REP DLY 0600-1000
# 1742  AD AP SFC COND NOT REP DLY 0600-1000
# 1743  AD AP SFC COND NOT REP DLY 0600-1000
# 1744  AD AP SFC COND NOT REP DLY 0600-1000
# 1745  AD AP SFC COND NOT REP DLY 0600-1000
# 1746  AD AP SFC COND NOT REP DLY 0600-1000
# 1747  AD AP SFC COND NOT REP DLY 0600-1000
# 1748  AD AP SFC COND NOT REP DLY 0600-1000
# 1749  AD AP SFC COND NOT REP DLY 0600-1000
# 1750  AD AP SFC COND NOT REP DLY 0600-1000
# 1751  AD AP SFC COND NOT REP DLY 0600-1000
# 1752  AD AP SFC COND NOT REP DLY 0600-1000
# 1753  AD AP SFC COND NOT REP DLY 0600-1000
# 1754  AD AP SFC COND NOT REP DLY 0600-1000
# 1755  AD AP SFC COND NOT REP DLY 0600-1000
# 1756  AD AP SFC COND NOT REP DLY 0600-1000
# 1757  AD AP SFC COND NOT REP DLY 0600-1000
# 1758  AD AP SFC COND NOT REP DLY 0600-1000
# 1759  AD AP SFC COND NOT REP DLY 0600-1000
# 1760  AD AP SFC COND NOT REP DLY 0600-1000
# 1761  AD AP SFC COND NOT REP DLY 0600-1000
# 1762  AD AP SFC COND NOT REP DLY 0600-1000
# 1763  AD AP SFC COND NOT REP DLY 0600-1000
# 1764  AD AP SFC COND NOT REP DLY 0600-1000
# 1765  AD AP SFC COND NOT REP DLY 0600-1000
# 1766  AD AP SFC COND NOT REP DLY 0600-1000
# 1767  AD AP SFC COND NOT REP DLY 0600-1000
# 1768  AD AP SFC COND NOT REP DLY 0600-1000
# 1769  AD AP SFC COND NOT REP DLY 0600-1000
# 1770  AD AP SFC COND NOT REP DLY 0600-1000
# 1771  AD AP SFC COND NOT REP DLY 0600-1000
# 1772  AD AP SFC COND NOT REP DLY 0600-1000
# 1773  AD AP SFC COND NOT REP DLY 0600-1000
# 1774  AD AP SFC COND NOT REP DLY 0600-1000
# 1775  AD AP SFC COND NOT REP DLY 0600-1000
# 1776  AD AP SFC COND NOT REP DLY 0600-1000
# 1777  AD AP SFC COND NOT REP DLY 0600-1000
#
# [142 rows x 5 columns]

# %%
#datetime_object = datetime.strptime('Jun 1 2005  1:33PM', '%b %d %Y %I:%M%p')
#datetime_object
#base = datetime.today()
#base
#base
import datetime as dt

max_end = max(notam_now['end_time'])
min_start = min(notam_now['start_time'])
print(base)
start = dt.datetime.strptime(min_start, "%Y-%m-%d %H:%M:%S.%f")
end = dt.datetime.strptime(max_end, "%Y-%m-%d %H:%M:%S.%f")
print(datetime_object)
difference = (end - start).total_seconds() / 60.0
print(difference)
date_list = [end - dt.timedelta(minutes=x) for x in range(0,int(difference),20)]
print(date_list)
# Out:
# 2019-05-31 06:00:00.0
# 2019-05-31 06:00:00
# 203340.0
# [datetime.datetime(2019, 5, 31, 6, 0), datetime.datetime(2019, 5, 31, 5, 40), datetime.datetime(2019, 5, 31, 5, 20), datetime.datetime(2019, 5, 31, 5, 0), datetime.datetime(2019, 5, 31, 4, 40), datetime.datetime(2019, 5, 31, 4, 20), datetime.datetime(2019, 5, 31, 4, 0), datetime.datetime(2019, 5, 31, 3, 40), datetime.datetime(2019, 5, 31, 3, 20), datetime.datetime(2019, 5, 31, 3, 0), datetime.datetime(2019, 5, 31, 2, 40), datetime.datetime(2019, 5, 31, 2, 20), datetime.datetime(2019, 5, 31, 2, 0), datetime.datetime(2019, 5, 31, 1, 40), datetime.datetime(2019, 5, 31, 1, 20), datetime.datetime(2019, 5, 31, 1, 0), datetime.datetime(2019, 5, 31, 0, 40), datetime.datetime(2019, 5, 31, 0, 20), datetime.datetime(2019, 5, 31, 0, 0), datetime.datetime(2019, 5, 30, 23, 40), datetime.datetime(2019, 5, 30, 23, 20), datetime.datetime(2019, 5, 30, 23, 0), datetime.datetime(2019, 5, 30, 22, 40), datetime.datetime(2019, 5, 30, 22, 20), datetime.datetime(2019, 5, 30, 22, 0), datetime.datetime(2019, 5, 30, 21, 40), datetime.datetime(2019, 5, 30, 21, 20), datetime.datetime(2019, 5, 30, 21, 0), datetime.datetime(2019, 5, 30, 20, 40), datetime.datetime(2019, 5, 30, 20, 20), datetime.datetime(2019, 5, 30, 20, 0), datetime.datetime(2019, 5, 30, 19, 40), datetime.datetime(2019, 5, 30, 19, 20), datetime.datetime(2019, 5, 30, 19, 0), datetime.datetime(2019, 5, 30, 18, 40), datetime.datetime(2019, 5, 30, 18, 20), datetime.datetime(2019, 5, 30, 18, 0), datetime.datetime(2019, 5, 30, 17, 40), datetime.datetime(2019, 5, 30, 17, 20), datetime.datetime(2019, 5, 30, 17, 0), datetime.datetime(2019, 5, 30, 16, 40), datetime.datetime(2019, 5, 30, 16, 20), datetime.datetime(2019, 5, 30, 16, 0), datetime.datetime(2019, 5, 30, 15, 40), datetime.datetime(2019, 5, 30, 15, 20), datetime.datetime(2019, 5, 30, 15, 0), datetime.datetime(2019, 5, 30, 14, 40), datetime.datetime(2019, 5, 30, 14, 20), datetime.datetime(2019, 5, 30, 14, 0), datetime.datetime(2019, 5, 30, 13, 40), datetime.datetime(2019, 5, 30, 13, 20), datetime.datetime(2019, 5, 30, 13, 0), datetime.datetime(2019, 5, 30, 12, 40), datetime.datetime(2019, 5, 30, 12, 20), datetime.datetime(2019, 5, 30, 12, 0), datetime.datetime(2019, 5, 30, 11, 40), datetime.datetime(2019, 5, 30, 11, 20), datetime.datetime(2019, 5, 30, 11, 0), datetime.datetime(2019, 5, 30, 10, 40), datetime.datetime(2019, 5, 30, 10, 20), datetime.datetime(2019, 5, 30, 10, 0), datetime.datetime(2019, 5, 30, 9, 40), datetime.datetime(2019, 5, 30, 9, 20), datetime.datetime(2019, 5, 30, 9, 0), datetime.datetime(2019, 5, 30, 8, 40), datetime.datetime(2019, 5, 30, 8, 20), datetime.datetime(2019, 5, 30, 8, 0), datetime.datetime(2019, 5, 30, 7, 40), datetime.datetime(2019, 5, 30, 7, 20), datetime.datetime(2019, 5, 30, 7, 0), datetime.datetime(2019, 5, 30, 6, 40), datetime.datetime(2019, 5, 30, 6, 20), datetime.datetime(2019, 5, 30, 6, 0), datetime.datetime(2019, 5, 30, 5, 40), datetime.datetime(2019, 5, 30, 5, 20), datetime.datetime(2019, 5, 30, 5, 0), datetime.datetime(2019, 5, 30, 4, 40), datetime.datetime(2019, 5, 30, 4, 20), datetime.datetime(2019, 5, 30, 4, 0), datetime.datetime(2019, 5, 30, 3, 40), datetime.datetime(2019, 5, 30, 3, 20), datetime.datetime(2019, 5, 30, 3, 0), datetime.datetime(2019, 5, 30, 2, 40), datetime.datetime(2019, 5, 30, 2, 20), datetime.datetime(2019, 5, 30, 2, 0), datetime.datetime(2019, 5, 30, 1, 40), datetime.datetime(2019, 5, 30, 1, 20), datetime.datetime(2019, 5, 30, 1, 0), datetime.datetime(2019, 5, 30, 0, 40), datetime.datetime(2019, 5, 30, 0, 20), datetime.datetime(2019, 5, 30, 0, 0), datetime.datetime(2019, 5, 29, 23, 40), datetime.datetime(2019, 5, 29, 23, 20), datetime.datetime(2019, 5, 29, 23, 0), datetime.datetime(2019, 5, 29, 22, 40), datetime.datetime(2019, 5, 29, 22, 20), datetime.datetime(2019, 5, 29, 22, 0), datetime.datetime(2019, 5, 29, 21, 40), datetime.datetime(2019, 5, 29, 21, 20), datetime.datetime(2019, 5, 29, 21, 0), datetime.datetime(2019, 5, 29, 20, 40), datetime.datetime(2019, 5, 29, 20, 20), da ...

# %%
df2 = pd.DataFrame(date_list[::-1], columns=['Time'])
print(df2)
# Out:
#                      Time
# 0     2019-01-10 01:20:00
# 1     2019-01-10 01:40:00
# 2     2019-01-10 02:00:00
# 3     2019-01-10 02:20:00
# 4     2019-01-10 02:40:00
# 5     2019-01-10 03:00:00
# 6     2019-01-10 03:20:00
# 7     2019-01-10 03:40:00
# 8     2019-01-10 04:00:00
# 9     2019-01-10 04:20:00
# 10    2019-01-10 04:40:00
# 11    2019-01-10 05:00:00
# 12    2019-01-10 05:20:00
# 13    2019-01-10 05:40:00
# 14    2019-01-10 06:00:00
# 15    2019-01-10 06:20:00
# 16    2019-01-10 06:40:00
# 17    2019-01-10 07:00:00
# 18    2019-01-10 07:20:00
# 19    2019-01-10 07:40:00
# 20    2019-01-10 08:00:00
# 21    2019-01-10 08:20:00
# 22    2019-01-10 08:40:00
# 23    2019-01-10 09:00:00
# 24    2019-01-10 09:20:00
# 25    2019-01-10 09:40:00
# 26    2019-01-10 10:00:00
# 27    2019-01-10 10:20:00
# 28    2019-01-10 10:40:00
# 29    2019-01-10 11:00:00
# 30    2019-01-10 11:20:00
# 31    2019-01-10 11:40:00
# 32    2019-01-10 12:00:00
# 33    2019-01-10 12:20:00
# 34    2019-01-10 12:40:00
# 35    2019-01-10 13:00:00
# 36    2019-01-10 13:20:00
# 37    2019-01-10 13:40:00
# 38    2019-01-10 14:00:00
# 39    2019-01-10 14:20:00
# 40    2019-01-10 14:40:00
# 41    2019-01-10 15:00:00
# 42    2019-01-10 15:20:00
# 43    2019-01-10 15:40:00
# 44    2019-01-10 16:00:00
# 45    2019-01-10 16:20:00
# 46    2019-01-10 16:40:00
# 47    2019-01-10 17:00:00
# 48    2019-01-10 17:20:00
# 49    2019-01-10 17:40:00
# ...                   ...
# 10117 2019-05-30 13:40:00
# 10118 2019-05-30 14:00:00
# 36    2019-01-10 13:20:00      0
# 37    2019-01-10 13:40:00      0
# 38    2019-01-10 14:00:00      0
# 39    2019-01-10 14:20:00      0
# 40    2019-01-10 14:40:00      0
# 41    2019-01-10 15:00:00      0
# 42    2019-01-10 15:20:00      0
# 43    2019-01-10 15:40:00      0
# 44    2019-01-10 16:00:00      0
# 45    2019-01-10 16:20:00      0
# 46    2019-01-10 16:40:00      0
# 47    2019-01-10 17:00:00      0
# 48    2019-01-10 17:20:00      0
# 49    2019-01-10 17:40:00      0
# ...                   ...    ...
# 10117 2019-05-30 13:40:00      0
# 10118 2019-05-30 14:00:00      0
# 10119 2019-05-30 14:20:00      0
# 10120 2019-05-30 14:40:00      0
# 10121 2019-05-30 15:00:00      0
# 10122 2019-05-30 15:20:00      0
# 10123 2019-05-30 15:40:00      0
# 10124 2019-05-30 16:00:00      0
# 10125 2019-05-30 16:20:00      0
# 10126 2019-05-30 16:40:00      0
# 10127 2019-05-30 17:00:00      0
# 10128 2019-05-30 17:20:00      0
# 10129 2019-05-30 17:40:00      0
# 10130 2019-05-30 18:00:00      0
# 10131 2019-05-30 18:20:00      0
# 10132 2019-05-30 18:40:00      0
# 10133 2019-05-30 19:00:00      0
# 10134 2019-05-30 19:20:00      0
# 10135 2019-05-30 19:40:00      0
# 10136 2019-05-30 20:00:00      0
# 10137 2019-05-30 20:20:00      0
# 10138 2019-05-30 20:40:00      0
# 10139 2019-05-30 21:00:00      0
# 10140 2019-05-30 21:20:00      0
# 10141 2019-05-30 21:40:00      0
# 10142 2019-05-30 22:00:00      0
# 10143 2019-05-30 22:20:00      0
# 10144 2019-05-30 22:40:00      0
# 10145 2019-05-30 23:00:00      0
# 10146 2019-05-30 23:20:00      0
# 10147 2019-05-30 23:40:00      0
# 10148 2019-05-31 00:00:00      0
# 10149 2019-05-31 00:20:00      0
# 10150 2019-05-31 00:40:00      0
# 10151 2019-05-31 01:00:00      0
# 10152 2019-05-31 01:20:00      0
# 10153 2019-05-31 01:40:00      0
# 10154 2019-05-31 02:00:00      0
# 10155 2019-05-31 02:20:00      0
# 10156 2019-05-31 02:40:00      0
# 10157 2019-05-31 03:00:00      0
# 10158 2019-05-31 03:20:00      0
# 10159 2019-05-31 03:40:00      0
# 10160 2019-05-31 04:00:00      0
# 10161 2019-05-31 04:20:00      0
# 10162 2019-05-31 04:40:00      0
# 10163 2019-05-31 05:00:00      0
# 10164 2019-05-31 05:20:00      0
# 10165 2019-05-31 05:40:00      0
# 10166 2019-05-31 06:00:00      0
#
# [10167 rows x 2 columns]

# %%
#df2['count'] = len(notam_now[(notam_now['start_time']<=df2['count']) & (notam_now['end_time']>=df2['count'])])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-b1766283a344> in <module>
# ----> 1 df2['count'] = len(notam_now[(notam_now['start_time']<=df2['count']) & (notam_now['end_time']>=df2['count'])])
#       2 #for index, row in notam_now.iterrows():
#       3     #row['start_time']))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1674
#    1675         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1676             raise ValueError("Can only compare identically-labeled "
#    1677                              "Series objects")
#    1678
#
# ValueError: Can only compare identically-labeled Series objects
